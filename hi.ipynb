# %%
from datasets.xbd_dataset import XBDDataset

ds = XBDDataset(
    root="data/sample_xbd",
    split="train",
    image_size=256
)

print(ds)
print(len(ds))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2314/2096430411.py in <cell line: 0>()
# ----> 1 from datasets.xbd_dataset import XBDDataset
#       2
#       3 ds = XBDDataset(
#       4     root="data/sample_xbd",
#       5     split="train",
#
# ModuleNotFoundError: No module named 'datasets.xbd_dataset'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %cd /home/jeevan/DAAPFL-RA/DAAPFL-RA
# Out:
# [Errno 2] No such file or directory: '/home/jeevan/DAAPFL-RA/DAAPFL-RA'
# /content

# %%
# !pwd
# !ls
# Out:
# /content
# sample_data

# %%
import os

print(os.getcwd())
# Out:
# /content
